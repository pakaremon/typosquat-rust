# %%
import json
import pandas as pd
import plotly.express as px

# %%
with open("/unique_dns and packages.json", "r") as json_file:
  data = json.load(json_file)

# %%
data_for_df = []

for item in data:
  data_for_df.append({'Hostname': item['Hostname'], 'Name_Count': len(item['Names'])})

df = pd.DataFrame(data_for_df)
df
# Out:
#                                              Hostname  Name_Count
# 0                                     index.crates.io      763026
# 1                       objects.githubusercontent.com        2037
# 2   ucad23aed486ebaae3350a254583.dl.dropboxusercon...          12
# 3                                     www.dropbox.com          23
# 4                                         ftp.gnu.org           8
# ..                                                ...         ...
# 77       vsagcache.oss-rg-china-mainland.aliyuncs.com           4
# 78                   nlkytncvwapfujviszuq.supabase.co           6
# 79                          chromium.googlesource.com          14
# 80                                   api.telegram.org           5
# 81                                         ip-api.com           5
#
# [82 rows x 2 columns]

# %%
fig = px.pie(df, values='Name_Count', names='Hostname', title='Name Count per Hostname')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
